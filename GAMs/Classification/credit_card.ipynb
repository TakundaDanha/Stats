# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

base = Path.cwd()

file_path_train = base.parent.parent /"Data"/"Binary Classification"/"credit"/"creditcard.csv"


print(file_path_train)
print(file_path_train.exists())

df = pd.read_csv(file_path_train)


df.head()
